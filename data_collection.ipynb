# %%
api_key = '<YOUR_API_KEY>'

# %%
import pandas as pd
import requests
import json

# %%
from tqdm import tqdm

# %%
df = pd.DataFrame()

for i in tqdm(range(1,501)):
        url = f'https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US\
        &page={i}&sort_by=popularity.desc&api_key={api_key}'
        response = requests.get(url)
        temporary_df = pd.DataFrame(response.json()['results'])
        
        df = pd.concat([df,temporary_df],ignore_index=True)
# Out:
# 100%|█████████████████████████████████████████| 500/500 [04:15<00:00,  1.96it/s]

# %%
df
# Out:
#       adult                     backdrop_path             genre_ids       id  \
# 0     False  /65MVgDa6YjSdqzh7YOA04mYkioo.jpg          [28, 80, 53]   668489
# 1     False  /fTrQsdMS2MUw00RnzH0r3JWHhts.jpg          [28, 80, 53]  1197306
# 2     False  /2Nti3gYAX513wvhp8IiLL6ZDyOm.jpg   [10751, 35, 12, 14]   950387
# 3     False  /1AWjIUgbZYaKbwUH5qoJaKCcRkf.jpg                  [99]  1471014
# 4     False   /Zes06xI18u47pblwRGTtqRm0R8.jpg      [28, 53, 80, 18]  1276073
# ...     ...                               ...                   ...      ...
# 9995  False  /vqoAvefKxBAg4xqbXwLDBG7QVyq.jpg    [10751, 35, 10770]    49041
# 9996  False  /7JztTSvp3D2U1oHDYoA1xlDI916.jpg          [35, 80, 53]   420034
# 9997  False  /8PKqcN6IREm2Xy43lzhPZ2ORzQi.jpg  [28, 27, 878, 10749]    27150
# 9998  False  /iaTZwxyXDojyDaCGke3cdLKnDDQ.jpg          [18, 28, 80]    92307
# 9999  False  /7ICPss8rtKmjda2kL9V5aVIjd9g.jpg              [18, 35]    19381
#
# ...

# %%
genre_details = requests.get(f'https://api.themoviedb.org/3/genre/movie/list?language=en&api_key={api_key}')
genre_df = pd.DataFrame(genre_details.json()['genres'])

# %%
df['genres'] = [[genre_df.name[genre_df.id==i].values[0] for i in x] for x in df.genre_ids]
df
# Out:
#       adult                     backdrop_path             genre_ids       id  \
# 0     False  /65MVgDa6YjSdqzh7YOA04mYkioo.jpg          [28, 80, 53]   668489
# 1     False  /fTrQsdMS2MUw00RnzH0r3JWHhts.jpg          [28, 80, 53]  1197306
# 2     False  /2Nti3gYAX513wvhp8IiLL6ZDyOm.jpg   [10751, 35, 12, 14]   950387
# 3     False  /1AWjIUgbZYaKbwUH5qoJaKCcRkf.jpg                  [99]  1471014
# 4     False   /Zes06xI18u47pblwRGTtqRm0R8.jpg      [28, 53, 80, 18]  1276073
# ...     ...                               ...                   ...      ...
# 9995  False  /vqoAvefKxBAg4xqbXwLDBG7QVyq.jpg    [10751, 35, 10770]    49041
# 9996  False  /7JztTSvp3D2U1oHDYoA1xlDI916.jpg          [35, 80, 53]   420034
# 9997  False  /8PKqcN6IREm2Xy43lzhPZ2ORzQi.jpg  [28, 27, 878, 10749]    27150
# 9998  False  /iaTZwxyXDojyDaCGke3cdLKnDDQ.jpg          [18, 28, 80]    92307
# 9999  False  /7ICPss8rtKmjda2kL9V5aVIjd9g.jpg              [18, 35]    19381
#
# ...

# %%
# !pip install kagglehub
import kagglehub

# Download latest version
path = kagglehub.dataset_download("ursmaheshj/iso-639-1-language-codes")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|███████████████████████████████████████| 1.42k/1.42k [00:00<00:00, 522kB/s]
# Extracting files...
# Path to dataset files: /Users/hrohra/.cache/kagglehub/datasets/ursmaheshj/iso-639-1-language-codes/versions/3
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# Cell In[11], line 8
#       5 path = kagglehub.dataset_download("ursmaheshj/iso-639-1-language-codes")
#       7 print("Path to dataset files:", path)
# ----> 8 language_df = pd.read_csv(path)
#       9 language_df.head(3)
#
# ...

# %%
language_df = pd.read_csv(path+"/ISO 639 1 Language Codes.csv")
language_df.head(3)
# Out:
#   ISO_code Language
# 0       aa     Afar
# 1       ab   Abkhaz
# 2       ae  Avestan

# %%
language_dict = dict(zip(language_df.ISO_code,language_df.Language))

# %%
df['original_language'].replace(language_dict,inplace=True)
df
# Out:
# /var/folders/d9/6vqyfc_d0w7bhcv1ly1twxqw0000gn/T/ipykernel_6342/499098179.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['original_language'].replace(language_dict,inplace=True)
#       adult                     backdrop_path             genre_ids       id  \
# 0     False  /65MVgDa6YjSdqzh7YOA04mYkioo.jpg          [28, 80, 53]   668489
# 1     False  /fTrQsdMS2MUw00RnzH0r3JWHhts.jpg          [28, 80, 53]  1197306
# 2     False  /2Nti3gYAX513wvhp8IiLL6ZDyOm.jpg   [10751, 35, 12, 14]   950387
# ...

# %%
df
# Out:
#       adult                     backdrop_path             genre_ids       id  \
# 0     False  /65MVgDa6YjSdqzh7YOA04mYkioo.jpg          [28, 80, 53]   668489
# 1     False  /fTrQsdMS2MUw00RnzH0r3JWHhts.jpg          [28, 80, 53]  1197306
# 2     False  /2Nti3gYAX513wvhp8IiLL6ZDyOm.jpg   [10751, 35, 12, 14]   950387
# 3     False  /1AWjIUgbZYaKbwUH5qoJaKCcRkf.jpg                  [99]  1471014
# 4     False   /Zes06xI18u47pblwRGTtqRm0R8.jpg      [28, 53, 80, 18]  1276073
# ...     ...                               ...                   ...      ...
# 9995  False  /vqoAvefKxBAg4xqbXwLDBG7QVyq.jpg    [10751, 35, 10770]    49041
# 9996  False  /7JztTSvp3D2U1oHDYoA1xlDI916.jpg          [35, 80, 53]   420034
# 9997  False  /8PKqcN6IREm2Xy43lzhPZ2ORzQi.jpg  [28, 27, 878, 10749]    27150
# 9998  False  /iaTZwxyXDojyDaCGke3cdLKnDDQ.jpg          [18, 28, 80]    92307
# 9999  False  /7ICPss8rtKmjda2kL9V5aVIjd9g.jpg              [18, 35]    19381
#
# ...

# %%
def watch_providers(movie_id):
    url = f"https://api.themoviedb.org/3/movie/{movie_id}/watch/providers"
    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJhMjY1YjhmMDIyMjM5Mjc3ZWMxMDE4OWE5NmFmOGE1YiIsIm5iZiI6MTc0MzQxMTcwNy40MzcsInN1YiI6IjY3ZWE1OWZiNTA0MGE3NWI0YWU1Njk3YiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.Oimi6r_0c2HeudBouTBRBiN6_LorwiEXR5VOle3IBA8"
    }
    response = requests.get(url, headers=headers).json()
    try:
        return extract_providers(response['results']['IN'])
    except Exception as e:
        return None

def extract_providers(response):
    provs =  set()
    l = list(response.values())[1:]
    for providers in l:
        for provider in providers:
            provs.add(provider['provider_name'])
    return provs

tqdm.pandas()

df['watch_providers'] = df['id'].progress_apply(watch_providers)
# Out:
# 100%|█████████████████████████████████████| 10000/10000 [57:30<00:00,  2.90it/s]

# %%
df.dropna(inplace=True)
df
# Out:
#       adult                     backdrop_path             genre_ids       id  \
# 0     False  /65MVgDa6YjSdqzh7YOA04mYkioo.jpg          [28, 80, 53]   668489
# 4     False   /Zes06xI18u47pblwRGTtqRm0R8.jpg      [28, 53, 80, 18]  1276073
# 6     False  /kFXtAwJYbRTqiyQpE9kDc8qEP3X.jpg              [28, 53]  1225915
# 14    False  /itEMpTHbWbgrROidzC2Tzb1hybv.jpg              [53, 28]  1233069
# 16    False  /hdHIjZxq3SWFqpAz4NFhdbud0iz.jpg             [27, 878]      348
# ...     ...                               ...                   ...      ...
# 9992  False  /96etD6qTLBfoGYZsLb9AAcSETjE.jpg              [28, 18]    20379
# 9993  False  /blEloSAWpCRamzP0ezJaeSYCc2m.jpg       [35, 18, 10749]    26686
# 9996  False  /7JztTSvp3D2U1oHDYoA1xlDI916.jpg          [35, 80, 53]   420034
# 9997  False  /8PKqcN6IREm2Xy43lzhPZ2ORzQi.jpg  [28, 27, 878, 10749]    27150
# 9998  False  /iaTZwxyXDojyDaCGke3cdLKnDDQ.jpg          [18, 28, 80]    92307
#
# ...

# %%
df.to_csv('df.csv')

# %%
data=df.loc[:, ['original_title', 'title', 'original_language', 'adult', 'overview', 'genres']]
data
# Out:
#                              original_title  \
# 0                                     Havoc
# 1                             A Working Man
# 2                         A Minecraft Movie
# 3                       Van Gogh by Vincent
# 4                                    新幹線大爆破
# ...                                     ...
# 9995  Pee-wee's Playhouse Christmas Special
# 9996                            Bank Robber
# 9997                            Silent Rage
# 9998                     The Final Comedown
# 9999                                Strike!
#
#                                       title original_language  adult  \
# 0                                     Havoc           English  False
# 1                             A Working Man           English  False
# 2                         A Minecraft Movie           English  False
# 3                       Van Gogh by Vincent           English  False
# 4                    Bullet Train Explosion          Japanese  False
# ...

# %%
df = pd.read_csv('df.csv')
df
# Out:
#       Unnamed: 0  adult                     backdrop_path  \
# 0              0  False  /65MVgDa6YjSdqzh7YOA04mYkioo.jpg
# 1              4  False   /Zes06xI18u47pblwRGTtqRm0R8.jpg
# 2              6  False  /kFXtAwJYbRTqiyQpE9kDc8qEP3X.jpg
# 3             14  False  /itEMpTHbWbgrROidzC2Tzb1hybv.jpg
# 4             16  False  /hdHIjZxq3SWFqpAz4NFhdbud0iz.jpg
# ...          ...    ...                               ...
# 5799        9992  False  /96etD6qTLBfoGYZsLb9AAcSETjE.jpg
# 5800        9993  False  /blEloSAWpCRamzP0ezJaeSYCc2m.jpg
# 5801        9996  False  /7JztTSvp3D2U1oHDYoA1xlDI916.jpg
# 5802        9997  False  /8PKqcN6IREm2Xy43lzhPZ2ORzQi.jpg
# 5803        9998  False  /iaTZwxyXDojyDaCGke3cdLKnDDQ.jpg
#
#                  genre_ids       id original_language  \
# 0             [28, 80, 53]   668489           English
# 1         [28, 53, 80, 18]  1276073          Japanese
# 2                 [28, 53]  1225915             Hindi
# ...

# %%
import ast
df['genres'] = df['genres'].apply(ast.literal_eval)
df['watch_providers'] = df['watch_providers'].apply(ast.literal_eval)
df
# Out:
#       Unnamed: 0  adult                     backdrop_path  \
# 0              0  False  /65MVgDa6YjSdqzh7YOA04mYkioo.jpg
# 1              4  False   /Zes06xI18u47pblwRGTtqRm0R8.jpg
# 2              6  False  /kFXtAwJYbRTqiyQpE9kDc8qEP3X.jpg
# 3             14  False  /itEMpTHbWbgrROidzC2Tzb1hybv.jpg
# 4             16  False  /hdHIjZxq3SWFqpAz4NFhdbud0iz.jpg
# ...          ...    ...                               ...
# 5799        9992  False  /96etD6qTLBfoGYZsLb9AAcSETjE.jpg
# 5800        9993  False  /blEloSAWpCRamzP0ezJaeSYCc2m.jpg
# 5801        9996  False  /7JztTSvp3D2U1oHDYoA1xlDI916.jpg
# 5802        9997  False  /8PKqcN6IREm2Xy43lzhPZ2ORzQi.jpg
# 5803        9998  False  /iaTZwxyXDojyDaCGke3cdLKnDDQ.jpg
#
#                  genre_ids       id original_language  \
# 0             [28, 80, 53]   668489           English
# 1         [28, 53, 80, 18]  1276073          Japanese
# 2                 [28, 53]  1225915             Hindi
# ...

# %%
# Out:
# 'Action'
